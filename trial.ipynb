# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('heart.csv')

# %%
df_x = data.iloc[:,1:]
df_y = data.iloc[:0]

# %%
x_train,x_test,y_train,y_test = train_test_split(df_x,df_y,test_size=0.2, random_state=4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-f7919b5242ee> in <module>
# ----> 1 x_train,x_test,y_train,y_test = train_test_split(df_x,df_y,test_size=0.2,random_state=4)
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_split.py in train_test_split(*arrays, **options)
#    2125         raise TypeError("Invalid parameters passed: %s" % str(options))
#    2126
# -> 2127     arrays = indexable(*arrays)
#    2128
#    2129     n_samples = _num_samples(arrays[0])
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in indexable(*iterables)
#     291     """
#     292     result = [_make_indexable(X) for X in iterables]
# --> 293     check_consistent_length(*result)
#     294     return result
#     295
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     254     uniques = np.unique(lengths)
#     255     if len(uniques) > 1:
# --> 256         raise ValueError("Found input variables with inconsistent numbers of"
#     257                          " samples: %r" % [int(l) for l in lengths])
#     258
#
# ValueError: Found input variables with inconsistent numbers of samples: [303, 0]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.tree import DecisionTreeClassifier

#Load the dataset
data = pd.read_csv("heart.csv")

#Train Test Split
y = data["target"]
X = data.drop("target", axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

#Building a Decision Tree Classifier
#dfc = DecisionTreeClassifier()
#dfc.fit(X_train,y_train)
#y_pred = dfc.predict(X_test)

#Observation of performance of DT classfier prediction
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))

#Building a Random Forest Classifier for k=50
rfc = RandomForestClassifier(n_estimators=400)
rfc.fit(X_train,y_train)
y_pred = rfc.predict(X_test)

#Observation of performance of RF classfier prediction
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.70      0.70        40
#            1       0.76      0.76      0.76        51
#
#     accuracy                           0.74        91
#    macro avg       0.73      0.73      0.73        91
# weighted avg       0.74      0.74      0.74        91
#
# [[28 12]
#  [12 39]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.72      0.77        40
#            1       0.80      0.88      0.84        51
#
#     accuracy                           0.81        91
#    macro avg       0.82      0.80      0.81        91
# weighted avg       0.81      0.81      0.81        91
#
# [[29 11]
#  [ 6 45]]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("heart.csv")
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
data.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %%
data.dtypes
for x in data:
    if data[x].dtypes == "int64":
        data[x] = data[x].astype(float)
        print (data[x].dtypes)
# Out:
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64
# float64

# %%
data.dtypes
X = data.drop('target',axis=1)
y = data['target']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators=100)
classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = classifier.predict(X_test)

# %%
df=pd.DataFrame({'Actual':y_test, 'Predicted':y_pred})
df
# Out:
#      Actual  Predicted
# 225     0.0        0.0
# 152     1.0        1.0
# 228     0.0        1.0
# 201     0.0        0.0
# 52      1.0        0.0
# 245     0.0        1.0
# 175     0.0        0.0
# 168     0.0        0.0
# 223     0.0        0.0
# 217     0.0        0.0
# 111     1.0        1.0
# 135     1.0        1.0
# 218     0.0        0.0
# 12      1.0        1.0
# 15      1.0        1.0
# 66      1.0        1.0
# 97      1.0        0.0
# 90      1.0        1.0
# 198     0.0        0.0
# 103     1.0        1.0
# 22      1.0        1.0
# 212     0.0        0.0
# 226     0.0        0.0
# 264     0.0        0.0
# 133     1.0        1.0
# 216     0.0        0.0
# 275     0.0        0.0
# 270     0.0        0.0
# 154     1.0        1.0
# 55      1.0        1.0
# 194     0.0        1.0

# %%
from sklearn import metrics
#print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
#print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
#print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
#print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-5d28e7e48758> in <module>
#       4 #print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
#       5 #print(classification_report(y_test, y_pred))
# ----> 6 print(confusion_matrix(y_test, y_pred))
#
# NameError: name 'confusion_matrix' is not defined

# %%
import seaborn as sns
plt.figure(figsize=(5, 7))


ax = sns.distplot(y, hist=False, color="r", label="Actual Value")
sns.distplot(y_pred, hist=False, color="b", label="Fitted Values" , ax=ax)


plt.title('Actual vs Fitted Values for Price')


plt.show()
plt.close()

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-217dfb1ddc3f> in <module>
# ----> 1 print("Accuracy:", accuracy_score(y_test, y_pred))
#
# NameError: name 'accuracy_score' is not defined

# %%
from sklearn.ensemble import BaggingClassifier
model = BaggingClassifier()
# fit the model on the whole dataset
model.fit(X_train, y_train)
# Out:
# BaggingClassifier()

# %%
y_pred = model.predict(X_test)

# %%
df=pd.DataFrame({'Actual':y_test, 'Predicted':y_pred})
df
#row = []
#yhat = model.predict(row)
#print('Predicted Class: %d' % yhat[0])
# Out:
#      Actual  Predicted
# 225     0.0        0.0
# 152     1.0        1.0
# 228     0.0        1.0
# 201     0.0        0.0
# 52      1.0        0.0
# 245     0.0        1.0
# 175     0.0        0.0
# 168     0.0        0.0
# 223     0.0        0.0
# 217     0.0        0.0
# 111     1.0        1.0
# 135     1.0        1.0
# 218     0.0        0.0
# 12      1.0        1.0
# 15      1.0        1.0
# 66      1.0        1.0
# 97      1.0        0.0
# 90      1.0        1.0
# 198     0.0        0.0
# 103     1.0        1.0
# 22      1.0        1.0
# 212     0.0        0.0
# 226     0.0        0.0
# 264     0.0        0.0
# 133     1.0        1.0
# 216     0.0        0.0
# 275     0.0        0.0
# 270     0.0        0.0
# 154     1.0        1.0
# 55      1.0        1.0
# 194     0.0        1.0

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.22580645161290322
# Mean Squared Error: 0.22580645161290322
# Root Mean Squared Error: 0.47519096331149147

# %%
import seaborn as sns
plt.figure(figsize=(5, 7))


ax = sns.distplot(y, hist=False, color="r", label="Actual Value")
sns.distplot(y_pred, hist=False, color="b", label="Fitted Values" , ax=ax)


plt.title('Actual vs Fitted Values for Price')


plt.show()
plt.close()

# %%
from numpy import loadtxt
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
# load data
dataset = loadtxt('heart.csv', delimiter=",")
# split data into X and y
X = dataset[:,0:8]
Y = dataset[:,8]
# split data into train and test sets
seed = 7
test_size = 0.33
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)
# fit model no training data
model = XGBClassifier()
model.fit(X_train, y_train)
# make predictions for test data
y_pred = model.predict(X_test)
predictions = [round(value) for value in y_pred]
# evaluate predictions
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-281b306153cc> in <module>
#       1 from numpy import loadtxt
# ----> 2 from xgboost import XGBClassifier
#       3 from sklearn.model_selection import train_test_split
#       4 from sklearn.metrics import accuracy_score
#       5 # load data
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
import xgboost
print(xgboost.__version__)
# Out:
# 1.4.2

# %%
row = [0.2929949,-4.21223056,-1.288332,-2.17849815,-0.64527665,2.58097719,0.28422388,-7.1827928,-1.91211104,2.73729512,0.81395695,3.96973717,-2.66939799,3.34692332,4.19791821,0.99990998,-0.30201875,-4.43170633,-2.82646737,0.44916808]
row = asarray([row])
# make a prediction
yhat = model.predict(row)
# summarize the prediction
print('Predicted Class: %d' % yhat[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-91785497ba1a> in <module>
#       1 row = [0.2929949,-4.21223056,-1.288332,-2.17849815,-0.64527665,2.58097719,0.28422388,-7.1827928,-1.91211104,2.73729512,0.81395695,3.96973717,-2.66939799,3.34692332,4.19791821,0.99990998,-0.30201875,-4.43170633,-2.82646737,0.44916808]
# ----> 2 row = asarray([row])
#       3 # make a prediction
#       4 yhat = model.predict(row)
#       5 # summarize the prediction
#
# NameError: name 'asarray' is not defined

# %%
import pandas as pd
from pandas import DataFrame
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.metrics import log_loss,roc_auc_score,precision_score,f1_score,recall_score,roc_curve,auc
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix,accuracy_score,fbeta_score,matthews_corrcoef
from sklearn import metrics
from sklearn.metrics import log_loss
# !pip install imblearn
from imblearn.metrics import geometric_mean_score
import warnings
import re
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt
warnings.filterwarnings('ignore')
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier,VotingClassifier
from sklearn.calibration import CalibratedClassifierCV
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.svm import SVC 
import xgboost as xgb
# !pip install vecstack
from vecstack import stacking
from scipy import stats
import os
# Out:
# Requirement already satisfied: imblearn in /home/nisarga/anaconda3/lib/python3.8/site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in /home/nisarga/anaconda3/lib/python3.8/site-packages (from imblearn) (0.8.0)
# Requirement already satisfied: numpy>=1.13.3 in /home/nisarga/anaconda3/lib/python3.8/site-packages (from imbalanced-learn->imblearn) (1.18.5)
# Requirement already satisfied: joblib>=0.11 in /home/nisarga/anaconda3/lib/python3.8/site-packages (from imbalanced-learn->imblearn) (0.16.0)
# Requirement already satisfied: scikit-learn>=0.24 in /home/nisarga/anaconda3/lib/python3.8/site-packages (from imbalanced-learn->imblearn) (0.24.2)
# Requirement already satisfied: scipy>=0.19.1 in /home/nisarga/anaconda3/lib/python3.8/site-packages (from imbalanced-learn->imblearn) (1.5.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/nisarga/anaconda3/lib/python3.8/site-packages (from scikit-learn>=0.24->imbalanced-learn->imblearn) (2.1.0)
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-21-e0f36f232949> in <module>
#      21 from sklearn.linear_model import LogisticRegression
#      22 from sklearn.ensemble import RandomForestClassifier,VotingClassifier
# ---> 23 from sklearn.calibration import CalibratedClassifierCV
#      24 from sklearn.neural_network import MLPClassifier
#      25 from sklearn.tree import DecisionTreeClassifier
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/calibration.py in <module>
#      31 )
#      32 from .utils.multiclass import check_classification_targets
# ---> 33 from .utils.fixes import delayed
#      34 from .utils.validation import check_is_fitted, check_consistent_length
#      35 from .utils.validation import _check_sample_weight
#
# ImportError: cannot import name 'delayed' from 'sklearn.utils.fixes' (/home/nisarga/anaconda3/lib/python3.8/site-packages/sklearn/utils/fixes.py)

# %%
dt = pd.read_csv('heart.csv')

# %%
# renaming features to proper name
dt.columns = ['age', 'sex', 'chest_pain_type', 'resting_blood_pressure', 'cholesterol', 'fasting_blood_sugar', 'rest_ecg', 'max_heart_rate_achieved',
       'exercise_induced_angina', 'st_depression', 'st_slope','target']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-e1c3fb99457b> in <module>
#       1 # renaming features to proper name
# ----> 2 dt.columns = ['age', 'sex', 'chest_pain_type', 'resting_blood_pressure', 'cholesterol', 'fasting_blood_sugar', 'rest_ecg', 'max_heart_rate_achieved',
#       3        'exercise_induced_angina', 'st_depression', 'st_slope','target']
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5285         try:
#    5286             object.__getattribute__(self, name)
# -> 5287             return object.__setattr__(self, name, value)
#    5288         except AttributeError:
#    5289             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
#     659
#     660     def _set_axis(self, axis, labels) -> None:
# --> 661         self._data.set_axis(axis, labels)
#     662         self._clear_item_cache()
#     663
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in set_axis(self, axis, new_labels)
#     175
#     176         if new_len != old_len:
# --> 177             raise ValueError(
#     178                 f"Length mismatch: Expected axis has {old_len} elements, new "
#     179                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 14 elements, new values have 12 elements
