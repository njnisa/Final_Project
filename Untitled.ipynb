# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from yellowbrick.model_selection import validation_curve 
data = pd.read_csv("ha.csv")
data.columns = ['age', 'sex', 'chest_pain_type', 'resting_blood_pressure', 'cholesterol', 'fasting_blood_sugar', 'rest_ecg', 'max_heart_rate_achieved',
       'exercise_induced_angina', 'st_depression', 'st_slope','target']
X = data.drop('target',axis=1)
y = data['target']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
classifier = RandomForestClassifier(n_estimators=100)
classifier.fit(X_train, y_train)
from sklearn.metrics import accuracy_score
threshold =0.450958
predicted_proba = classifier.predict_proba(X_test)
pr = (predicted_proba [:,1] >= threshold).astype('int')
accuracy = accuracy_score(y_test, pr)
print(accuracy*100)
num = np.arange(1,100,10)
#print(validation_curve(RandomForestClassifier(), X, y, param_name="max_depth", n_jobs=-1,param_range=np.arange(1, 11), cv=10, scoring="accuracy"))
train_scoreNum, test_scoreNum = validation_curve(RandomForestClassifier(),X , y , param_name = 'max_samples', param_range=num, cv = 10,scoring="accuracy", n_jobs=-1)
# Out:
# 92.85714285714286
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-6747fe3da207> in <module>
#      21 num = np.arange(1,100,10)
#      22 #print(validation_curve(RandomForestClassifier(), X, y, param_name="max_depth", n_jobs=-1,param_range=np.arange(1, 11), cv=10, scoring="accuracy"))
# ---> 23 train_scoreNum, test_scoreNum = validation_curve(RandomForestClassifier(),X , y , param_name = 'max_samples', param_range=num, cv = 10,scoring="accuracy", n_jobs=-1)
#
# TypeError: cannot unpack non-iterable ValidationCurve object
